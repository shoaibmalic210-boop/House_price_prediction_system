# %% [markdown]
# # Exploratory Data Analysis (EDA) Notebook
#
# This notebook performs exploratory data analysis on the House Price Prediction dataset to understand the data distribution, relationships, and identify potential issues.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("G:\datasets\House_price_prediction.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\KING AMIR\AppData\Local\Temp\ipykernel_11440\1849627723.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv("G:\datasets\House_price_prediction.csv")

# %%
df.describe()
# Out:
#           Unnamed: 0   property_id    location_id         price  \
# count  168446.000000  1.684460e+05  168446.000000  1.684460e+05
# mean    84222.500000  1.559626e+07    4375.936395  1.776576e+07
# std     48626.316059  2.251207e+06    3776.561581  3.531003e+07
# min         0.000000  8.657500e+04       1.000000  0.000000e+00
# 25%     42111.250000  1.488320e+07    1058.000000  1.750000e+05
# 50%     84222.500000  1.665851e+07    3286.000000  8.500000e+06
# 75%    126333.750000  1.708662e+07    7220.000000  1.950000e+07
# max    168445.000000  1.735772e+07   14220.000000  2.000000e+09
#
#        latitude(N,S)  longitude(E,W)          baths       bedrooms  \
# count  168446.000000   168446.000000  168446.000000  168446.000000
# mean       29.859519       71.239804       2.874227       3.179422
# std         3.807870        3.133042       2.463400       1.971401
# min        11.052446       25.906027       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168446 entries, 0 to 168445
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      168446 non-null  int64
#  1   property_id     168446 non-null  int64
#  2   location_id     168446 non-null  int64
#  3   page_url        168446 non-null  object
#  4   property_type   168446 non-null  object
#  5   price           168446 non-null  int64
#  6   location        168446 non-null  object
#  7   city            168446 non-null  object
#  8   province_name   168446 non-null  object
#  9   latitude(N,S)   168446 non-null  float64
#  10  longitude(E,W)  168446 non-null  float64
#  11  baths           168446 non-null  int64
#  12  purpose         168446 non-null  object
#  13  bedrooms        168446 non-null  int64
#  14  date_added      168446 non-null  object
#  15  agency          124375 non-null  object
# ...

# %%
df.shape
# Out:
# (168446, 18)

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
sns.pairplot(df)

# %%
df.corr(numeric_only=True)
# Out:
#                 Unnamed: 0  property_id  location_id     price  latitude(N,S)  \
# Unnamed: 0        1.000000     0.831999    -0.001230 -0.045190       0.007725
# property_id       0.831999     1.000000     0.006564 -0.029669      -0.010461
# location_id      -0.001230     0.006564     1.000000 -0.098426      -0.293129
# price            -0.045190    -0.029669    -0.098426  1.000000      -0.071193
# latitude(N,S)     0.007725    -0.010461    -0.293129 -0.071193       1.000000
# longitude(E,W)    0.011502    -0.002722    -0.282903 -0.019225       0.926888
# baths            -0.127251    -0.101769    -0.121941  0.230205       0.053107
# bedrooms         -0.076331    -0.066577    -0.138452  0.314145       0.030961
# Total_Area        0.005018     0.002461    -0.002041  0.008168       0.001775
#
#                 longitude(E,W)     baths  bedrooms  Total_Area
# Unnamed: 0            0.011502 -0.127251 -0.076331    0.005018
# property_id          -0.002722 -0.101769 -0.066577    0.002461
# ...

# %%
sns.boxplot(y= df['price'], data=df)
# Out:
# <Axes: ylabel='price'>

# %%
df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
